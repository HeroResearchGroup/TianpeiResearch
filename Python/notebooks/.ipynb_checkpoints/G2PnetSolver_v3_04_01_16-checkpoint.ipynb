# %% [markdown]
# # G$^2$Pnet: The Grassmanian Gaussian Process Network
# We check the implementation of G2PnetSolver (ver 4.) class in ../src/
#
# Created by Tianpei Xie, 04/01/2016
#
# Last Edit 04/01/2016

# %%
# %reset
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.metrics.pairwise import rbf_kernel, pairwise_kernels
import GPy
import GPy.util as gutil

# %matplotlib inline 
plt.close('all')
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# /Applications/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
Ifsavefig =  False
Ifsavedata = False
trail = 13

# %% [markdown]
# The network generating

# %%
size = 40
color_map = {0:'r', 1:'c', 2:'y'}
#center = np.zeros(2)
#center[1] = 1
center = None

n = 40
m = 0
G0= nx.barbell_graph(n,m) 
#generate the bar-bell graph, which consists of two fully connected component and a path connecting them 

label0 = np.zeros([2*n,1])
label0[n:2*n] = np.ones([n,1])
#### labeling of the cluster
for node in G0.nodes():
    G0.node[node]['category'] = int(label0[node,0])

# %%
####generate the eigenspace of normalized Laplacian
k = 3
nnodes = nx.adjacency_matrix(G0).shape[0]

ncv=max(2*k+1,int(np.sqrt(nnodes)))

eigenvalues,eigenvectors= sp.sparse.linalg.eigsh(nx.laplacian_matrix(G0).asfptype(), k=k, \
                                                which='SM', return_eigenvectors = True, ncv=ncv)
index=np.argsort(eigenvalues)[1:k] # 0 index is zero eigenvalue    
pos_spectral_mat = np.real(eigenvectors[:,index]) #pos_spectral_mat is the spectral location of the nodes
pos_spectral_df = pd.DataFrame(data=pos_spectral_mat, columns=['PX','PY'], dtype=float)
pos_spectral_df['LABEL'] = label0

# %% [markdown]
# The node attributes generating

# %%
T= 2
c = 2*np.pi*0.8
data_np = np.zeros([nnodes, T])
column_name = []
for t in np.arange(1,T+1):
    temp1 = np.multiply(pos_spectral_df['PX'].apply(lambda x: np.exp(-c*t*x)).values, \
                          pos_spectral_df['PY'].apply(lambda y: np.cos(c*t*y)).values)
    data_np[:,t-1] = temp1
    if t == 1:
        column_name = str(t-1)+"_cos"
    else:    
        column_name = [column_name, str(t-1)+"_cos"]

sigma = 0.1        
data_np = np.add(data_np, sigma*np.random.randn(nnodes, T))    
data_df = pd.DataFrame(data=data_np, columns=column_name, dtype=float)
data_df['LABEL'] = label0

# %%
if Ifsavedata:
    nx.write_adjlist(G0, "../data/04_01_2016_experiment"+ str(trail) +".adjlist",delimiter=',')
    nx.write_edgelist(G0, "../data/04_01_2016_experiment" + str(trail) + ".edgelist")

    np.savez("../data/04_01_2016_experiment" + str(trail) + "_data.npz", pos_spectral_mat, data_np, label0)
    data_df.to_csv("../data/04_01_2016_experiment" + str(trail) + "_X.csv", index_label= 'ID')
    pos_spectral_df.to_csv("../data/04_01_2016_experiment" +  str(trail)  + "_U.csv", index_label= 'ID')

# %% [markdown]
# if Ifsavedata:
#     nx.write_adjlist(G0, "../data/experiment_bad_03_31_2016.adjlist",delimiter=',')
#     nx.write_edgelist(G0, "../data/experiment_bad_03_31_2016.edgelist")
#
#     np.savez("../data/experiment_bad_data_03_31_2016.npz", pos_spectral_mat, data_np, label0)
#     data_df.to_csv("../data/experiment_bad_X_03_31_2016.csv", index_label= 'ID')
#     pos_spectral_df.to_csv("../data/experiment_bad_U_03_31_2016.csv", index_label= 'ID')

# %%
X= data_np
U= pos_spectral_mat
nsample, ndim = X.shape
_ , ndim_latent = U.shape

kern = GPy.kern.RBF(2)

# %% [markdown]
# Import from the G2PnetSolver_v4.py

# %%
import sys
import os
dirorg = os.path.dirname(os.getcwd())
sys.path.insert(0, dirorg+"/src/")

# %%
import G2PnetSolver_v4 #G2PnetSolver_v2
#from imp import reload
#reload(G2PnetSolver_v2)

# %%
from G2PnetSolver_v4 import  G2PnetSolver as Solver
from G2PnetSolver_v4 import  Grassmann_update, check_step

# %%
choice = "near"

# %%
np.random.seed(seed=150)

if choice == "random":
    print("Random Initialization")
    Temp = np.random.randn(nsample, nsample)
    Temp_sym = (Temp + Temp.T) / 2 
    _, U_temp = np.linalg.eig(Temp_sym)
    U_test = U_temp[:, np.arange(ndim_latent)]
    U0 = U_test
elif choice == "near":
    print("Initialization in neigborhood.")
    U0 = U

eta0 = 0.75
np.random.seed(seed=160)
G_temp = np.random.randn(nsample, ndim_latent) / (np.sqrt(nsample * ndim_latent))
H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(U0)),G_temp)
print(str(check_step(H_temp, eta0)))
while not check_step(H_temp, eta0):
    np.random.seed(seed=160)
    G_temp = np.random.randn(nsample, ndim_latent) / np.sqrt(nsample * ndim_latent)
    H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(U0)),G_temp)
U_init = Grassmann_update(U0, H_temp, eta=eta0)
# Out:
# Initialization in neigborhood.
# True

# %%
sp.linalg.svdvals(H_temp)*eta0
# Out:
# array([ 0.52292797,  0.50843383])

# %% [markdown]
# ### Compute the gradient $\frac{dL}{dU}$
# The loss function is given as negative log-likelihood of Gaussian process
#
# \begin{align}
# \mathcal{L}(\beta, \sigma, \mathbf{U}) &= \frac{pN}{2}\log(2\pi)+\frac{p}{2}\log\det(\mathbf{K}_{\beta, \sigma, \mathbf{U}})+\frac{1}{2}\text{tr}\left(\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{−1}\mathbf{X}\mathbf{X}^T\right) + \frac{\lambda}{2} \|\mathbf{U}\mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2}
# \end{align}
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{K}$
# \begin{align}
# \mathbf{T}&= 2\mathbf{T}_{0} - \text{diag}\left(\mathbf{T}_{0}\right),\\
# \mathbf{T}_{0} &= \frac{1}{2}\left(\mathbf{I} - \mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}\mathbf{X}\mathbf{X}^T/p \right)\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}, \\
# \mathbf{K}_{r,s} &= K_{\sigma}\left(\mathbf{U}_{r,:} , \mathbf{U}_{s,:}\right) + \beta \delta_{r,s}
# \end{align}
#
# For rbf kernel,
# \begin{align}
# \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{Z}}}{\partial \mathbf{U}_{m,j}}
# &= -\frac{l^{2}}{\sigma^2} \exp\left(-\frac{1}{2\sigma^2} \|\mathbf{U}_{m} -  \mathbf{U}_{n}\|^{2} \right)\left[2\left( \mathbf{U}_{m,i} - \mathbf{U}_{n,j} \right)\right]
# \end{align}
#
# The differential of the second norm term
# \begin{align}
# \frac{d}{d\mathbf{U}}\frac{1}{2}\|\mathbf{U} \mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2} &=
# \frac{d}{d\mathbf{U}}\frac{1}{2}\left[\text{tr}\left(\mathbf{U} \mathbf{U}^{T}\right) - \text{tr}\left(\mathbf{U}_{L}\mathbf{U}_{L}^{T}\mathbf{U}\mathbf{U}^{T}\right)\right]\\
# &= \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U}
# \end{align}
#
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{U}$
# \begin{align}
# \frac{\partial\mathcal{L}}{\partial\mathbf{U}} &= \left[\text{tr}\left( \mathbf{T} \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{U}}}{\partial \mathbf{U}_{m,j}} \right)\right]_{m,j} + \lambda \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U},
# \end{align}

# %%
if Ifsavedata:
    U_columns = [str(i) for i in np.arange(ndim_latent)]
    U_df = pd.DataFrame(data = U_init, columns=U_columns, dtype= float)
    if choice == "random":
        U_df['RANDOM'] = np.ones([nsample, 1])
    elif choice == "near":
        U_df['RANDOM'] = np.zeros([nsample, 1])
    
    U_df.to_csv("../data/04_01_16_" + str(trail)  + "_U_init.csv")
    #U_df.to_csv("../data/U_init_bad_03_31_16.csv")

# %%
add_reg = True
lambda_array = np.array([0.01]) #10, 1, 0.001
eta = 0.0001
max_iters = 600
kern_array = [GPy.kern.RBF(2) for i in np.arange(len(lambda_array))]
kern_grass_array = [GPy.kern.RBF(2) for i in np.arange(len(lambda_array))]
solver_array = []
hist_nll_eu_array = []
hist_nll_grass_array = []
hist_Hsig_array = []

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 30.0)
plt.style.use('seaborn-white')

for i, lambda_var in enumerate(lambda_array): 
    ax = plt.subplot(5,1,i+1)
    solver = Solver(X=X, U=U_init, kernel=kern_array[i], U_ref= U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_eu, hist_eta, hist_kern_eu = solver.optimize(max_iters = max_iters)
    solver_array.append(solver)
    hist_nll_eu_array.append(hist_nll_eu)
    
    
    solver2 = Solver(X=X, U=U_init, kernel=kern_grass_array[i], U_ref = U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_grass, hist_eta, hist_kern_grass = solver2.optimize(max_iters = max_iters, optimizor = "grad_descent_grass")
    hist_Hsig_array.append(solver2.hist_Hsig)
    
    solver_array.append(solver2)
    hist_nll_grass_array.append(hist_nll_grass)
        
    # %xdel solver
    # %xdel solver2
# Out:
# kernel initialization ...
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i     f              |g|
#     00s02  005   3.230805e+02   6.148537e+01
#     00s08  017   1.360628e+02   1.590053e+01
#     00s10  023   1.356189e+02   2.224611e-08
#     00s11  025   1.356189e+02   3.167811e-10
# Runtime:     00s11
# Optimization status: Converged
#
# negative log-likelihood compute
# [step   0] neg-log-likelihood -605.132060 stepsize 0.0001
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   1] neg-log-likelihood -632.690383 stepsize 0.0001
# [step   2] neg-log-likelihood -638.187525 stepsize 0.0001
# [step   3] neg-log-likelihood -631.099812 stepsize 0.0001
# [step   4] neg-log-likelihood -621.913161 stepsize 0.0001
# [step   5] neg-log-likelihood -621.767344 stepsize 0.0001
# [step   6] neg-log-likelihood -629.484831 stepsize 0.0001
# [step   7] neg-log-likelihood -641.233453 stepsize 0.0001
# [step   8] neg-log-likelihood -653.001983 stepsize 0.0001
# [step   9] neg-log-likelihood -665.408860 stepsize 0.0001
# [step  10] neg-log-likelihood -676.765334 stepsize 0.0001
# [step  11] neg-log-likelihood -691.668575 stepsize 0.0001
# [step  12] neg-log-likelihood -708.775017 stepsize 0.0001
# [step  13] neg-log-likelihood -724.013226 stepsize 0.0001
# [step  14] neg-log-likelihood -732.108577 stepsize 0.0001
# [step  15] neg-log-likelihood -744.756170 stepsize 0.0001
# [step  16] neg-log-likelihood -761.256133 stepsize 0.0001
# [step  17] neg-log-likelihood -770.638908 stepsize 0.0001
# [step  18] neg-log-likelihood -783.315067 stepsize 0.0001
# [step  19] neg-log-likelihood -795.186759 stepsize 0.0001
# [step  20] neg-log-likelihood -802.359834 stepsize 0.0001
# [step  21] neg-log-likelihood -810.730090 stepsize 0.0001
# [step  22] neg-log-likelihood -819.479898 stepsize 0.0001
# [step  23] neg-log-likelihood -828.665221 stepsize 0.0001
# [step  24] neg-log-likelihood -838.285797 stepsize 0.0001
# [step  25] neg-log-likelihood -848.169405 stepsize 0.0001
# [step  26] neg-log-likelihood -857.812719 stepsize 0.0001
# [step  27] neg-log-likelihood -867.153797 stepsize 0.0001
# [step  28] neg-log-likelihood -876.719335 stepsize 0.0001
# [step  29] neg-log-likelihood -886.803532 stepsize 0.0001
# [step  30] neg-log-likelihood -897.452314 stepsize 0.0001
# [step  31] neg-log-likelihood -907.830455 stepsize 0.0001
# [step  32] neg-log-likelihood -917.631889 stepsize 0.0001
# [step  33] neg-log-likelihood -927.910029 stepsize 0.0001
# [step  34] neg-log-likelihood -939.669865 stepsize 0.0001
# [step  35] neg-log-likelihood -952.581502 stepsize 0.0001
# [step  36] neg-log-likelihood -957.280692 stepsize 0.0001
# [step  37] neg-log-likelihood -965.839009 stepsize 0.0001
# [step  38] neg-log-likelihood -974.611448 stepsize 0.0001
# [step  39] neg-log-likelihood -983.717191 stepsize 0.0001
# [step  40] neg-log-likelihood -992.788322 stepsize 0.0001
# [step  41] neg-log-likelihood -1001.740014 stepsize 0.0001
# [step  42] neg-log-likelihood -1009.698791 stepsize 0.0001
# [step  43] neg-log-likelihood -1019.133106 stepsize 0.0001
# [step  44] neg-log-likelihood -1026.057065 stepsize 0.0001
# [step  45] neg-log-likelihood -1034.928575 stepsize 0.0001
# [step  46] neg-log-likelihood -1043.954757 stepsize 0.0001
# [step  47] neg-log-likelihood -1055.019400 stepsize 0.0001
# [step  48] neg-log-likelihood -1065.073458 stepsize 0.0001
# [step  49] neg-log-likelihood -1073.384600 stepsize 0.0001
# [step  50] neg-log-likelihood -1079.865022 stepsize 0.0001
# [step  51] neg-log-likelihood -1089.388895 stepsize 0.0001
# [step  52] neg-log-likelihood -1098.576657 stepsize 0.0001
# [step  53] neg-log-likelihood -1106.929290 stepsize 0.0001
# [step  54] neg-log-likelihood -1110.633037 stepsize 0.0001
# [step  55] neg-log-likelihood -1121.981961 stepsize 0.0001
# [step  56] neg-log-likelihood -1129.526147 stepsize 0.0001
# [step  57] neg-log-likelihood -1135.121113 stepsize 0.0001
# [step  58] neg-log-likelihood -1140.020568 stepsize 0.0001
# [step  59] neg-log-likelihood -1148.606712 stepsize 0.0001
# [step  60] neg-log-likelihood -1152.784452 stepsize 0.0001
# [step  61] neg-log-likelihood -1160.090526 stepsize 0.0001
# [step  62] neg-log-likelihood -1163.286108 stepsize 0.0001
# [step  63] neg-log-likelihood -1166.981023 stepsize 0.0001
# [step  64] neg-log-likelihood -1174.213866 stepsize 0.0001
# [step  65] neg-log-likelihood -1180.216897 stepsize 0.0001
# [step  66] neg-log-likelihood -1184.078935 stepsize 0.0001
# [step  67] neg-log-likelihood -1188.620883 stepsize 0.0001
# [step  68] neg-log-likelihood -1190.510349 stepsize 0.0001
# [step  69] neg-log-likelihood -1192.628144 stepsize 0.0001
# [step  70] neg-log-likelihood -1197.593675 stepsize 0.0001
# [step  71] neg-log-likelihood -1198.747165 stepsize 0.0001
# [step  72] neg-log-likelihood -1202.232087 stepsize 0.0001
# [step  73] neg-log-likelihood -1207.806125 stepsize 0.0001
# [step  74] neg-log-likelihood -1210.662192 stepsize 0.0001
# [step  75] neg-log-likelihood -1213.186331 stepsize 0.0001
# [step  76] neg-log-likelihood -1218.164375 stepsize 0.0001
# [step  77] neg-log-likelihood -1219.549812 stepsize 0.0001
# [step  78] neg-log-likelihood -1224.963089 stepsize 0.0001
# [step  79] neg-log-likelihood -1230.149005 stepsize 0.0001
# [step  80] neg-log-likelihood -1228.338567 stepsize 0.0001
# [step  81] neg-log-likelihood -1230.561854 stepsize 0.0001
# [step  82] neg-log-likelihood -1233.686589 stepsize 0.0001
# [step  83] neg-log-likelihood -1240.783103 stepsize 0.0001
# [step  84] neg-log-likelihood -1241.641360 stepsize 0.0001
# [step  85] neg-log-likelihood -1247.388458 stepsize 0.0001
# [step  86] neg-log-likelihood -1249.043782 stepsize 0.0001
# [step  87] neg-log-likelihood -1251.487137 stepsize 0.0001
# [step  88] neg-log-likelihood -1256.644396 stepsize 0.0001
# [step  89] neg-log-likelihood -1259.681840 stepsize 0.0001
# [step  90] neg-log-likelihood -1261.553503 stepsize 0.0001
# [step  91] neg-log-likelihood -1266.458445 stepsize 0.0001
# [step  92] neg-log-likelihood -1269.037136 stepsize 0.0001
# [step  93] neg-log-likelihood -1271.769941 stepsize 0.0001
# [step  94] neg-log-likelihood -1274.810876 stepsize 0.0001
# [step  95] neg-log-likelihood -1283.725729 stepsize 0.0001
# [step  96] neg-log-likelihood -1282.351202 stepsize 0.0001
# [step  97] neg-log-likelihood -1288.206862 stepsize 0.0001
# [step  98] neg-log-likelihood -1292.128134 stepsize 0.0001
# [step  99] neg-log-likelihood -1296.387989 stepsize 0.0001
# [step 100] neg-log-likelihood -1299.530662 stepsize 0.0001
# [step 101] neg-log-likelihood -1300.583467 stepsize 0.0001
# [step 102] neg-log-likelihood -1307.861098 stepsize 0.0001
# [step 103] neg-log-likelihood -1311.361436 stepsize 0.0001
# [step 104] neg-log-likelihood -1316.257161 stepsize 0.0001
# [step 105] neg-log-likelihood -1318.156547 stepsize 0.0001
# [step 106] neg-log-likelihood -1324.458756 stepsize 0.0001
# [step 107] neg-log-likelihood -1325.167368 stepsize 0.0001
# [step 108] neg-log-likelihood -1334.076703 stepsize 0.0001
# [step 109] neg-log-likelihood -1335.015820 stepsize 0.0001
# [step 110] neg-log-likelihood -1336.155642 stepsize 0.0001
# [step 111] neg-log-likelihood -1338.241500 stepsize 0.0001
# [step 112] neg-log-likelihood -1344.038606 stepsize 0.0001
# [step 113] neg-log-likelihood -1347.108502 stepsize 0.0001
# [step 114] neg-log-likelihood -1351.281582 stepsize 0.0001
# [step 115] neg-log-likelihood -1357.740657 stepsize 0.0001
# [step 116] neg-log-likelihood -1361.693190 stepsize 0.0001
# [step 117] neg-log-likelihood -1359.077408 stepsize 0.0001
# [step 118] neg-log-likelihood -1367.571090 stepsize 0.0001
# [step 119] neg-log-likelihood -1369.286982 stepsize 0.0001
# [step 120] neg-log-likelihood -1368.237380 stepsize 0.0001
# [step 121] neg-log-likelihood -1372.140186 stepsize 0.0001
# [step 122] neg-log-likelihood -1379.961803 stepsize 0.0001
# [step 123] neg-log-likelihood -1378.568745 stepsize 0.0001
# [step 124] neg-log-likelihood -1382.302949 stepsize 0.0001
# [step 125] neg-log-likelihood -1382.178163 stepsize 0.0001
# [step 126] neg-log-likelihood -1384.903255 stepsize 0.0001
# [step 127] neg-log-likelihood -1385.324301 stepsize 0.0001
# [step 128] neg-log-likelihood -1390.288042 stepsize 0.0001
# [step 129] neg-log-likelihood -1398.199704 stepsize 0.0001
# [step 130] neg-log-likelihood -1397.569225 stepsize 0.0001
# [step 131] neg-log-likelihood -1397.662263 stepsize 0.0001
# [step 132] neg-log-likelihood -1402.391633 stepsize 0.0001
# [step 133] neg-log-likelihood -1402.122365 stepsize 0.0001
# [step 134] neg-log-likelihood -1404.989539 stepsize 0.0001
# [step 135] neg-log-likelihood -1409.397962 stepsize 0.0001
# [step 136] neg-log-likelihood -1411.176554 stepsize 0.0001
# [step 137] neg-log-likelihood -1412.506894 stepsize 0.0001
# [step 138] neg-log-likelihood -1414.849742 stepsize 0.0001
# [step 139] neg-log-likelihood -1416.310286 stepsize 0.0001
# [step 140] neg-log-likelihood -1419.506428 stepsize 0.0001
# [step 141] neg-log-likelihood -1421.881492 stepsize 0.0001
# [step 142] neg-log-likelihood -1422.927476 stepsize 0.0001
# [step 143] neg-log-likelihood -1422.301625 stepsize 0.0001
# [step 144] neg-log-likelihood -1425.142592 stepsize 0.0001
# [step 145] neg-log-likelihood -1430.798611 stepsize 0.0001
# [step 146] neg-log-likelihood -1431.860835 stepsize 0.0001
# [step 147] neg-log-likelihood -1431.702861 stepsize 0.0001
# [step 148] neg-log-likelihood -1434.683108 stepsize 0.0001
# [step 149] neg-log-likelihood -1436.039835 stepsize 0.0001
# [step 150] neg-log-likelihood -1437.706609 stepsize 0.0001
# [step 151] neg-log-likelihood -1441.458105 stepsize 0.0001
# [step 152] neg-log-likelihood -1440.071970 stepsize 0.0001
# [step 153] neg-log-likelihood -1442.227542 stepsize 0.0001
# [step 154] neg-log-likelihood -1445.802114 stepsize 0.0001
# [step 155] neg-log-likelihood -1449.555224 stepsize 0.0001
# [step 156] neg-log-likelihood -1450.647899 stepsize 0.0001
# [step 157] neg-log-likelihood -1449.572909 stepsize 0.0001
# [step 158] neg-log-likelihood -1448.911888 stepsize 0.0001
# [step 159] neg-log-likelihood -1447.684442 stepsize 0.0001
# [step 160] neg-log-likelihood -1448.999898 stepsize 0.0001
# [step 161] neg-log-likelihood -1445.578459 stepsize 0.0001
# [step 162] neg-log-likelihood -1450.625935 stepsize 0.0001
# [step 163] neg-log-likelihood -1450.550790 stepsize 0.0001
# [step 164] neg-log-likelihood -1450.679843 stepsize 0.0001
# [step 165] neg-log-likelihood -1448.615591 stepsize 0.0001
# [step 166] neg-log-likelihood -1450.064213 stepsize 0.0001
# [step 167] neg-log-likelihood -1451.132102 stepsize 0.0001
# [step 168] neg-log-likelihood -1450.190655 stepsize 0.0001
# [step 169] neg-log-likelihood -1452.384186 stepsize 0.0001
# [step 170] neg-log-likelihood -1449.217357 stepsize 0.0001
# [step 171] neg-log-likelihood -1451.101826 stepsize 0.0001
# [step 172] neg-log-likelihood -1451.321831 stepsize 0.0001
# [step 173] neg-log-likelihood -1455.698702 stepsize 0.0001
# [step 174] neg-log-likelihood -1453.672012 stepsize 0.0001
# [step 175] neg-log-likelihood -1454.555357 stepsize 0.0001
# [step 176] neg-log-likelihood -1456.073591 stepsize 0.0001
# [step 177] neg-log-likelihood -1455.441036 stepsize 0.0001
# [step 178] neg-log-likelihood -1460.426540 stepsize 0.0001
# [step 179] neg-log-likelihood -1456.417122 stepsize 0.0001
# [step 180] neg-log-likelihood -1454.204290 stepsize 0.0001
# [step 181] neg-log-likelihood -1457.266654 stepsize 0.0001
# [step 182] neg-log-likelihood -1456.320460 stepsize 0.0001
# [step 183] neg-log-likelihood -1456.674576 stepsize 0.0001
# [step 184] neg-log-likelihood -1459.078372 stepsize 0.0001
# [step 185] neg-log-likelihood -1457.567215 stepsize 0.0001
# [step 186] neg-log-likelihood -1460.840099 stepsize 0.0001
# [step 187] neg-log-likelihood -1458.455973 stepsize 0.0001
# [step 188] neg-log-likelihood -1457.148618 stepsize 0.0001
# [step 189] neg-log-likelihood -1459.914632 stepsize 0.0001
# [step 190] neg-log-likelihood -1458.809111 stepsize 0.0001
# [step 191] neg-log-likelihood -1459.634685 stepsize 0.0001
# [step 192] neg-log-likelihood -1457.720391 stepsize 0.0001
# [step 193] neg-log-likelihood -1457.768893 stepsize 0.0001
# [step 194] neg-log-likelihood -1456.168444 stepsize 0.0001
# [step 195] neg-log-likelihood -1460.595383 stepsize 0.0001
# [step 196] neg-log-likelihood -1461.705122 stepsize 0.0001
# [step 197] neg-log-likelihood -1460.701772 stepsize 0.0001
# [step 198] neg-log-likelihood -1461.249150 stepsize 0.0001
# [step 199] neg-log-likelihood -1461.831018 stepsize 0.0001
# [step 200] neg-log-likelihood -1460.925322 stepsize 0.0001
# [step 201] neg-log-likelihood -1463.509723 stepsize 0.0001
# [step 202] neg-log-likelihood -1463.629507 stepsize 0.0001
# [step 203] neg-log-likelihood -1461.681880 stepsize 0.0001
# [step 204] neg-log-likelihood -1465.154100 stepsize 0.0001
# [step 205] neg-log-likelihood -1462.958707 stepsize 0.0001
# [step 206] neg-log-likelihood -1463.063501 stepsize 0.0001
# [step 207] neg-log-likelihood -1464.614096 stepsize 0.0001
# [step 208] neg-log-likelihood -1464.879985 stepsize 0.0001
# [step 209] neg-log-likelihood -1463.852151 stepsize 0.0001
# [step 210] neg-log-likelihood -1466.354347 stepsize 0.0001
# [step 211] neg-log-likelihood -1464.825963 stepsize 0.0001
# [step 212] neg-log-likelihood -1468.149382 stepsize 0.0001
# [step 213] neg-log-likelihood -1465.686229 stepsize 0.0001
# [step 214] neg-log-likelihood -1465.691553 stepsize 0.0001
# [step 215] neg-log-likelihood -1465.065177 stepsize 0.0001
# [step 216] neg-log-likelihood -1465.672192 stepsize 0.0001
# [step 217] neg-log-likelihood -1469.917566 stepsize 0.0001
# [step 218] neg-log-likelihood -1470.944551 stepsize 0.0001
# [step 219] neg-log-likelihood -1468.017380 stepsize 0.0001
# [step 220] neg-log-likelihood -1469.974178 stepsize 0.0001
# [step 221] neg-log-likelihood -1469.516072 stepsize 0.0001
# [step 222] neg-log-likelihood -1471.863671 stepsize 0.0001
# [step 223] neg-log-likelihood -1470.931283 stepsize 0.0001
# [step 224] neg-log-likelihood -1475.003035 stepsize 0.0001
# [step 225] neg-log-likelihood -1472.685322 stepsize 0.0001
# [step 226] neg-log-likelihood -1472.691651 stepsize 0.0001
# [step 227] neg-log-likelihood -1472.673095 stepsize 0.0001
# [step 228] neg-log-likelihood -1472.804065 stepsize 0.0001
# [step 229] neg-log-likelihood -1471.533862 stepsize 0.0001
# [step 230] neg-log-likelihood -1474.188188 stepsize 0.0001
# [step 231] neg-log-likelihood -1473.044254 stepsize 0.0001
# [step 232] neg-log-likelihood -1475.055404 stepsize 0.0001
# [step 233] neg-log-likelihood -1475.272584 stepsize 0.0001
# [step 234] neg-log-likelihood -1474.439185 stepsize 0.0001
# [step 235] neg-log-likelihood -1474.909412 stepsize 0.0001
# [step 236] neg-log-likelihood -1479.451286 stepsize 0.0001
# [step 237] neg-log-likelihood -1475.884198 stepsize 0.0001
# [step 238] neg-log-likelihood -1476.423790 stepsize 0.0001
# [step 239] neg-log-likelihood -1476.669026 stepsize 0.0001
# [step 240] neg-log-likelihood -1484.213094 stepsize 0.0001
# [step 241] neg-log-likelihood -1476.646155 stepsize 0.0001
# [step 242] neg-log-likelihood -1478.135215 stepsize 0.0001
# [step 243] neg-log-likelihood -1477.351825 stepsize 0.0001
# [step 244] neg-log-likelihood -1483.451460 stepsize 0.0001
# [step 245] neg-log-likelihood -1481.770427 stepsize 0.0001
# [step 246] neg-log-likelihood -1479.565582 stepsize 0.0001
# [step 247] neg-log-likelihood -1481.836076 stepsize 0.0001
# [step 248] neg-log-likelihood -1481.210946 stepsize 0.0001
# [step 249] neg-log-likelihood -1481.727796 stepsize 0.0001
# [step 250] neg-log-likelihood -1481.274504 stepsize 0.0001
# [step 251] neg-log-likelihood -1482.990596 stepsize 0.0001
# [step 252] neg-log-likelihood -1483.277091 stepsize 0.0001
# [step 253] neg-log-likelihood -1481.904914 stepsize 0.0001
# [step 254] neg-log-likelihood -1482.056689 stepsize 0.0001
# [step 255] neg-log-likelihood -1484.957044 stepsize 0.0001
# [step 256] neg-log-likelihood -1486.759218 stepsize 0.0001
# [step 257] neg-log-likelihood -1483.839512 stepsize 0.0001
# [step 258] neg-log-likelihood -1485.851326 stepsize 0.0001
# [step 259] neg-log-likelihood -1485.385294 stepsize 0.0001
# [step 260] neg-log-likelihood -1485.412534 stepsize 0.0001
# [step 261] neg-log-likelihood -1486.366353 stepsize 0.0001
# [step 262] neg-log-likelihood -1486.511359 stepsize 0.0001
# [step 263] neg-log-likelihood -1486.329962 stepsize 0.0001
# [step 264] neg-log-likelihood -1487.908297 stepsize 0.0001
# [step 265] neg-log-likelihood -1490.001906 stepsize 0.0001
# [step 266] neg-log-likelihood -1490.645231 stepsize 0.0001
# [step 267] neg-log-likelihood -1488.385614 stepsize 0.0001
# [step 268] neg-log-likelihood -1488.791890 stepsize 0.0001
# [step 269] neg-log-likelihood -1488.320776 stepsize 0.0001
# [step 270] neg-log-likelihood -1489.176775 stepsize 0.0001
# [step 271] neg-log-likelihood -1491.226690 stepsize 0.0001
# [step 272] neg-log-likelihood -1492.067196 stepsize 0.0001
# [step 273] neg-log-likelihood -1493.726849 stepsize 0.0001
# [step 274] neg-log-likelihood -1491.557466 stepsize 0.0001
# [step 275] neg-log-likelihood -1494.901381 stepsize 0.0001
# [step 276] neg-log-likelihood -1495.472577 stepsize 0.0001
# [step 277] neg-log-likelihood -1498.220583 stepsize 0.0001
# [step 278] neg-log-likelihood -1495.431960 stepsize 0.0001
# [step 279] neg-log-likelihood -1494.430116 stepsize 0.0001
# [step 280] neg-log-likelihood -1494.929764 stepsize 0.0001
# [step 281] neg-log-likelihood -1493.596552 stepsize 0.0001
# [step 282] neg-log-likelihood -1495.034483 stepsize 0.0001
# [step 283] neg-log-likelihood -1496.290168 stepsize 0.0001
# [step 284] neg-log-likelihood -1499.053314 stepsize 0.0001
# [step 285] neg-log-likelihood -1498.538816 stepsize 0.0001
# [step 286] neg-log-likelihood -1500.218231 stepsize 0.0001
# [step 287] neg-log-likelihood -1499.601066 stepsize 0.0001
# [step 288] neg-log-likelihood -1500.346523 stepsize 0.0001
# [step 289] neg-log-likelihood -1498.211180 stepsize 0.0001
# [step 290] neg-log-likelihood -1498.990497 stepsize 0.0001
# [step 291] neg-log-likelihood -1500.028629 stepsize 0.0001
# [step 292] neg-log-likelihood -1499.440113 stepsize 0.0001
# [step 293] neg-log-likelihood -1500.388154 stepsize 0.0001
# [step 294] neg-log-likelihood -1503.532754 stepsize 0.0001
# [step 295] neg-log-likelihood -1502.034197 stepsize 0.0001
# [step 296] neg-log-likelihood -1501.451084 stepsize 0.0001
# [step 297] neg-log-likelihood -1502.892180 stepsize 0.0001
# [step 298] neg-log-likelihood -1502.621622 stepsize 0.0001
# [step 299] neg-log-likelihood -1503.100121 stepsize 0.0001
# [step 300] neg-log-likelihood -1503.214561 stepsize 0.0001
# [step 301] neg-log-likelihood -1503.447159 stepsize 0.0001
# [step 302] neg-log-likelihood -1512.563123 stepsize 0.0001
# [step 303] neg-log-likelihood -1503.251280 stepsize 0.0001
# [step 304] neg-log-likelihood -1505.348260 stepsize 0.0001
# [step 305] neg-log-likelihood -1505.420334 stepsize 0.0001
# [step 306] neg-log-likelihood -1505.506562 stepsize 0.0001
# [step 307] neg-log-likelihood -1506.629791 stepsize 0.0001
# [step 308] neg-log-likelihood -1506.768361 stepsize 0.0001
# [step 309] neg-log-likelihood -1505.538503 stepsize 0.0001
# [step 310] neg-log-likelihood -1511.697987 stepsize 0.0001
# [step 311] neg-log-likelihood -1505.687982 stepsize 0.0001
# [step 312] neg-log-likelihood -1505.809977 stepsize 0.0001
# [step 313] neg-log-likelihood -1508.762872 stepsize 0.0001
# [step 314] neg-log-likelihood -1509.771055 stepsize 0.0001
# [step 315] neg-log-likelihood -1504.712064 stepsize 0.0001
# [step 316] neg-log-likelihood -1507.859852 stepsize 0.0001
# [step 317] neg-log-likelihood -1508.717921 stepsize 0.0001
# [step 318] neg-log-likelihood -1515.249522 stepsize 0.0001
# [step 319] neg-log-likelihood -1510.985743 stepsize 0.0001
# [step 320] neg-log-likelihood -1508.836836 stepsize 0.0001
# [step 321] neg-log-likelihood -1511.925376 stepsize 0.0001
# [step 322] neg-log-likelihood -1511.413514 stepsize 0.0001
# [step 323] neg-log-likelihood -1510.024078 stepsize 0.0001
# [step 324] neg-log-likelihood -1513.440985 stepsize 0.0001
# [step 325] neg-log-likelihood -1510.427883 stepsize 0.0001
# [step 326] neg-log-likelihood -1509.146823 stepsize 0.0001
# [step 327] neg-log-likelihood -1512.133682 stepsize 0.0001
# [step 328] neg-log-likelihood -1517.036536 stepsize 0.0001
# [step 329] neg-log-likelihood -1515.806495 stepsize 0.0001
# [step 330] neg-log-likelihood -1515.038396 stepsize 0.0001
# [step 331] neg-log-likelihood -1516.131659 stepsize 0.0001
# [step 332] neg-log-likelihood -1512.638978 stepsize 0.0001
# [step 333] neg-log-likelihood -1514.817781 stepsize 0.0001
# [step 334] neg-log-likelihood -1515.574216 stepsize 0.0001
# [step 335] neg-log-likelihood -1517.797787 stepsize 0.0001
# [step 336] neg-log-likelihood -1517.133968 stepsize 0.0001
# [step 337] neg-log-likelihood -1522.638210 stepsize 0.0001
# [step 338] neg-log-likelihood -1516.793771 stepsize 0.0001
# [step 339] neg-log-likelihood -1517.543415 stepsize 0.0001
# [step 340] neg-log-likelihood -1518.310244 stepsize 0.0001
# [step 341] neg-log-likelihood -1516.870339 stepsize 0.0001
# [step 342] neg-log-likelihood -1520.212393 stepsize 0.0001
# [step 343] neg-log-likelihood -1518.801982 stepsize 0.0001
# [step 344] neg-log-likelihood -1516.668399 stepsize 0.0001
# [step 345] neg-log-likelihood -1518.108310 stepsize 0.0001
# [step 346] neg-log-likelihood -1520.422361 stepsize 0.0001
# [step 347] neg-log-likelihood -1520.288774 stepsize 0.0001
# [step 348] neg-log-likelihood -1520.141018 stepsize 0.0001
# [step 349] neg-log-likelihood -1520.294778 stepsize 0.0001
# [step 350] neg-log-likelihood -1520.676691 stepsize 0.0001
# [step 351] neg-log-likelihood -1523.161282 stepsize 0.0001
# [step 352] neg-log-likelihood -1525.635133 stepsize 0.0001
# [step 353] neg-log-likelihood -1521.008674 stepsize 0.0001
# [step 354] neg-log-likelihood -1525.999544 stepsize 0.0001
# [step 355] neg-log-likelihood -1526.175448 stepsize 0.0001
# [step 356] neg-log-likelihood -1524.539594 stepsize 0.0001
# [step 357] neg-log-likelihood -1526.024788 stepsize 0.0001
# [step 358] neg-log-likelihood -1525.325629 stepsize 0.0001
# [step 359] neg-log-likelihood -1526.715365 stepsize 0.0001
# [step 360] neg-log-likelihood -1523.945474 stepsize 0.0001
# [step 361] neg-log-likelihood -1524.918717 stepsize 0.0001
# [step 362] neg-log-likelihood -1525.784404 stepsize 0.0001
# [step 363] neg-log-likelihood -1527.033835 stepsize 0.0001
# [step 364] neg-log-likelihood -1526.824078 stepsize 0.0001
# [step 365] neg-log-likelihood -1529.554476 stepsize 0.0001
# [step 366] neg-log-likelihood -1527.298737 stepsize 0.0001
# [step 367] neg-log-likelihood -1526.323528 stepsize 0.0001
# [step 368] neg-log-likelihood -1529.720836 stepsize 0.0001
# [step 369] neg-log-likelihood -1528.247323 stepsize 0.0001
# [step 370] neg-log-likelihood -1527.815922 stepsize 0.0001
# [step 371] neg-log-likelihood -1525.861471 stepsize 0.0001
# [step 372] neg-log-likelihood -1527.279367 stepsize 0.0001
# [step 373] neg-log-likelihood -1528.626624 stepsize 0.0001
# [step 374] neg-log-likelihood -1531.184741 stepsize 0.0001
# [step 375] neg-log-likelihood -1527.846048 stepsize 0.0001
# [step 376] neg-log-likelihood -1534.060281 stepsize 0.0001
# [step 377] neg-log-likelihood -1530.054463 stepsize 0.0001
# [step 378] neg-log-likelihood -1532.750523 stepsize 0.0001
# [step 379] neg-log-likelihood -1530.040950 stepsize 0.0001
# [step 380] neg-log-likelihood -1530.528364 stepsize 0.0001
# [step 381] neg-log-likelihood -1531.482446 stepsize 0.0001
# [step 382] neg-log-likelihood -1536.341289 stepsize 0.0001
# [step 383] neg-log-likelihood -1534.325577 stepsize 0.0001
# [step 384] neg-log-likelihood -1534.496539 stepsize 0.0001
# [step 385] neg-log-likelihood -1534.013840 stepsize 0.0001
# [step 386] neg-log-likelihood -1536.860089 stepsize 0.0001
# [step 387] neg-log-likelihood -1531.254381 stepsize 0.0001
# [step 388] neg-log-likelihood -1539.175923 stepsize 0.0001
# [step 389] neg-log-likelihood -1530.783200 stepsize 0.0001
# [step 390] neg-log-likelihood -1533.391229 stepsize 0.0001
# [step 391] neg-log-likelihood -1534.954938 stepsize 0.0001
# [step 392] neg-log-likelihood -1535.432721 stepsize 0.0001
# [step 393] neg-log-likelihood -1534.267837 stepsize 0.0001
# [step 394] neg-log-likelihood -1536.080466 stepsize 0.0001
# [step 395] neg-log-likelihood -1535.311861 stepsize 0.0001
# [step 396] neg-log-likelihood -1536.608424 stepsize 0.0001
# [step 397] neg-log-likelihood -1535.116392 stepsize 0.0001
# [step 398] neg-log-likelihood -1534.867362 stepsize 0.0001
# [step 399] neg-log-likelihood -1536.286936 stepsize 0.0001
# [step 400] neg-log-likelihood -1534.073514 stepsize 0.0001
# [step 401] neg-log-likelihood -1533.737885 stepsize 0.0001
# [step 402] neg-log-likelihood -1536.576124 stepsize 0.0001
# [step 403] neg-log-likelihood -1533.091258 stepsize 0.0001
# [step 404] neg-log-likelihood -1534.313459 stepsize 0.0001
# [step 405] neg-log-likelihood -1533.274231 stepsize 0.0001
# [step 406] neg-log-likelihood -1538.785790 stepsize 0.0001
# [step 407] neg-log-likelihood -1540.568239 stepsize 0.0001
# [step 408] neg-log-likelihood -1536.076044 stepsize 0.0001
# [step 409] neg-log-likelihood -1535.364935 stepsize 0.0001
# [step 410] neg-log-likelihood -1538.392283 stepsize 0.0001
# [step 411] neg-log-likelihood -1542.138583 stepsize 0.0001
# [step 412] neg-log-likelihood -1534.088124 stepsize 0.0001
# [step 413] neg-log-likelihood -1534.713119 stepsize 0.0001
# [step 414] neg-log-likelihood -1538.005170 stepsize 0.0001
# [step 415] neg-log-likelihood -1533.618030 stepsize 0.0001
# [step 416] neg-log-likelihood -1535.386166 stepsize 0.0001
# [step 417] neg-log-likelihood -1534.422157 stepsize 0.0001
# [step 418] neg-log-likelihood -1535.197437 stepsize 0.0001
# [step 419] neg-log-likelihood -1534.529622 stepsize 0.0001
# [step 420] neg-log-likelihood -1533.436115 stepsize 0.0001
# [step 421] neg-log-likelihood -1537.336776 stepsize 0.0001
# [step 422] neg-log-likelihood -1533.186470 stepsize 0.0001
# [step 423] neg-log-likelihood -1534.850494 stepsize 0.0001
# [step 424] neg-log-likelihood -1534.351485 stepsize 0.0001
# [step 425] neg-log-likelihood -1534.847410 stepsize 0.0001
# [step 426] neg-log-likelihood -1532.569413 stepsize 0.0001
# [step 427] neg-log-likelihood -1535.917176 stepsize 0.0001
# [step 428] neg-log-likelihood -1533.820083 stepsize 0.0001
# [step 429] neg-log-likelihood -1536.108898 stepsize 0.0001
# [step 430] neg-log-likelihood -1532.685433 stepsize 0.0001
# [step 431] neg-log-likelihood -1532.894554 stepsize 0.0001
# [step 432] neg-log-likelihood -1531.699670 stepsize 0.0001
# [step 433] neg-log-likelihood -1534.195511 stepsize 0.0001
# [step 434] neg-log-likelihood -1530.210152 stepsize 0.0001
# [step 435] neg-log-likelihood -1533.560416 stepsize 0.0001
# [step 436] neg-log-likelihood -1528.685545 stepsize 0.0001
# [step 437] neg-log-likelihood -1528.631748 stepsize 0.0001
# [step 438] neg-log-likelihood -1529.426334 stepsize 0.0001
# [step 439] neg-log-likelihood -1528.620650 stepsize 0.0001
# [step 440] neg-log-likelihood -1531.313596 stepsize 0.0001
# [step 441] neg-log-likelihood -1528.486681 stepsize 0.0001
# [step 442] neg-log-likelihood -1526.100118 stepsize 0.0001
# [step 443] neg-log-likelihood -1526.726536 stepsize 0.0001
# [step 444] neg-log-likelihood -1524.674773 stepsize 0.0001
# [step 445] neg-log-likelihood -1524.538577 stepsize 0.0001
# [step 446] neg-log-likelihood -1526.864043 stepsize 0.0001
# [step 447] neg-log-likelihood -1525.747891 stepsize 0.0001
# [step 448] neg-log-likelihood -1523.141610 stepsize 0.0001
# [step 449] neg-log-likelihood -1522.603724 stepsize 0.0001
# [step 450] neg-log-likelihood -1521.203326 stepsize 0.0001
# [step 451] neg-log-likelihood -1523.139450 stepsize 0.0001
# [step 452] neg-log-likelihood -1522.546412 stepsize 0.0001
# [step 453] neg-log-likelihood -1519.508334 stepsize 0.0001
# [step 454] neg-log-likelihood -1520.621366 stepsize 0.0001
# [step 455] neg-log-likelihood -1518.610173 stepsize 0.0001
# [step 456] neg-log-likelihood -1519.883594 stepsize 0.0001
# [step 457] neg-log-likelihood -1515.563498 stepsize 0.0001
# [step 458] neg-log-likelihood -1515.627856 stepsize 0.0001
# [step 459] neg-log-likelihood -1516.811942 stepsize 0.0001
# [step 460] neg-log-likelihood -1511.229948 stepsize 0.0001
# [step 461] neg-log-likelihood -1514.004336 stepsize 0.0001
# [step 462] neg-log-likelihood -1511.199860 stepsize 0.0001
# [step 463] neg-log-likelihood -1515.723109 stepsize 0.0001
# [step 464] neg-log-likelihood -1509.699192 stepsize 0.0001
# [step 465] neg-log-likelihood -1509.040204 stepsize 0.0001
# [step 466] neg-log-likelihood -1508.210960 stepsize 0.0001
# [step 467] neg-log-likelihood -1507.972755 stepsize 0.0001
# [step 468] neg-log-likelihood -1510.239415 stepsize 0.0001
# [step 469] neg-log-likelihood -1508.163645 stepsize 0.0001
# [step 470] neg-log-likelihood -1505.466566 stepsize 0.0001
# [step 471] neg-log-likelihood -1504.143960 stepsize 0.0001
# [step 472] neg-log-likelihood -1503.623868 stepsize 0.0001
# [step 473] neg-log-likelihood -1498.396374 stepsize 0.0001
# [step 474] neg-log-likelihood -1496.981623 stepsize 0.0001
# [step 475] neg-log-likelihood -1499.846809 stepsize 0.0001
# [step 476] neg-log-likelihood -1495.247496 stepsize 0.0001
# [step 477] neg-log-likelihood -1497.918736 stepsize 0.0001
# [step 478] neg-log-likelihood -1496.965218 stepsize 0.0001
# [step 479] neg-log-likelihood -1489.485336 stepsize 0.0001
# [step 480] neg-log-likelihood -1488.965353 stepsize 0.0001
# [step 481] neg-log-likelihood -1488.753326 stepsize 0.0001
# [step 482] neg-log-likelihood -1483.966151 stepsize 0.0001
# [step 483] neg-log-likelihood -1485.723029 stepsize 0.0001
# [step 484] neg-log-likelihood -1482.135225 stepsize 0.0001
# [step 485] neg-log-likelihood -1482.522745 stepsize 0.0001
# [step 486] neg-log-likelihood -1478.564156 stepsize 0.0001
# [step 487] neg-log-likelihood -1475.976139 stepsize 0.0001
# [step 488] neg-log-likelihood -1475.996382 stepsize 0.0001
# [step 489] neg-log-likelihood -1473.000669 stepsize 0.0001
# [step 490] neg-log-likelihood -1472.780904 stepsize 0.0001
# [step 491] neg-log-likelihood -1468.520836 stepsize 0.0001
# [step 492] neg-log-likelihood -1467.311326 stepsize 0.0001
# [step 493] neg-log-likelihood -1461.306675 stepsize 0.0001
# [step 494] neg-log-likelihood -1459.058589 stepsize 0.0001
# [step 495] neg-log-likelihood -1453.667097 stepsize 0.0001
# [step 496] neg-log-likelihood -1450.647500 stepsize 0.0001
# [step 497] neg-log-likelihood -1450.848849 stepsize 0.0001
# [step 498] neg-log-likelihood -1443.943467 stepsize 0.0001
# [step 499] neg-log-likelihood -1442.049579 stepsize 0.0001
# [step 500] neg-log-likelihood -1433.795452 stepsize 0.0001
# [step 501] neg-log-likelihood -1429.818635 stepsize 0.0001
# [step 502] neg-log-likelihood -1427.100164 stepsize 0.0001
# [step 503] neg-log-likelihood -1415.033263 stepsize 0.0001
# [step 504] neg-log-likelihood -1409.330965 stepsize 0.0001
# [step 505] neg-log-likelihood -1399.627714 stepsize 0.0001
# [step 506] neg-log-likelihood -1394.960374 stepsize 0.0001
# [step 507] neg-log-likelihood -1382.798705 stepsize 0.0001
# [step 508] neg-log-likelihood -1371.150224 stepsize 0.0001
# [step 509] neg-log-likelihood -1361.056220 stepsize 0.0001
# [step 510] neg-log-likelihood -1352.857465 stepsize 0.0001
# [step 511] neg-log-likelihood -1343.970808 stepsize 0.0001
# [step 512] neg-log-likelihood -1330.046007 stepsize 0.0001
# [step 513] neg-log-likelihood -1318.537741 stepsize 0.0001
# [step 514] neg-log-likelihood -1309.695197 stepsize 0.0001
# [step 515] neg-log-likelihood -1300.279075 stepsize 0.0001
# [step 516] neg-log-likelihood -1289.832314 stepsize 0.0001
# [step 517] neg-log-likelihood -1277.834908 stepsize 0.0001
# [step 518] neg-log-likelihood -1272.317797 stepsize 0.0001
# [step 519] neg-log-likelihood -1267.513666 stepsize 0.0001
# [step 520] neg-log-likelihood -1259.365347 stepsize 0.0001
# [step 521] neg-log-likelihood -1250.927582 stepsize 0.0001
# [step 522] neg-log-likelihood -1246.055983 stepsize 0.0001
# [step 523] neg-log-likelihood -1242.452906 stepsize 0.0001
# [step 524] neg-log-likelihood -1235.453946 stepsize 0.0001
# [step 525] neg-log-likelihood -1229.716046 stepsize 0.0001
# [step 526] neg-log-likelihood -1229.863992 stepsize 0.0001
# [step 527] neg-log-likelihood -1221.502068 stepsize 0.0001
# [step 528] neg-log-likelihood -1217.260280 stepsize 0.0001
# [step 529] neg-log-likelihood -1214.380665 stepsize 0.0001
# [step 530] neg-log-likelihood -1210.919106 stepsize 0.0001
# [step 531] neg-log-likelihood -1207.426222 stepsize 0.0001
# [step 532] neg-log-likelihood -1202.386420 stepsize 0.0001
# [step 533] neg-log-likelihood -1201.368172 stepsize 0.0001
# [step 534] neg-log-likelihood -1194.024393 stepsize 0.0001
# [step 535] neg-log-likelihood -1190.182802 stepsize 0.0001
# [step 536] neg-log-likelihood -1189.730728 stepsize 0.0001
# [step 537] neg-log-likelihood -1185.528753 stepsize 0.0001
# [step 538] neg-log-likelihood -1181.195693 stepsize 0.0001
# [step 539] neg-log-likelihood -1175.931169 stepsize 0.0001
# [step 540] neg-log-likelihood -1174.870736 stepsize 0.0001
# [step 541] neg-log-likelihood -1169.980505 stepsize 0.0001
# [step 542] neg-log-likelihood -1168.517417 stepsize 0.0001
# [step 543] neg-log-likelihood -1161.309301 stepsize 0.0001
# [step 544] neg-log-likelihood -1160.006250 stepsize 0.0001
# [step 545] neg-log-likelihood -1158.958882 stepsize 0.0001
# [step 546] neg-log-likelihood -1153.236003 stepsize 0.0001
# [step 547] neg-log-likelihood -1151.863221 stepsize 0.0001
# [step 548] neg-log-likelihood -1151.688319 stepsize 0.0001
# [step 549] neg-log-likelihood -1143.934494 stepsize 0.0001
# [step 550] neg-log-likelihood -1140.115814 stepsize 0.0001
# [step 551] neg-log-likelihood -1138.478264 stepsize 0.0001
# [step 552] neg-log-likelihood -1137.913717 stepsize 0.0001
# [step 553] neg-log-likelihood -1136.785301 stepsize 0.0001
# [step 554] neg-log-likelihood -1132.242060 stepsize 0.0001
# [step 555] neg-log-likelihood -1128.509710 stepsize 0.0001
# [step 556] neg-log-likelihood -1123.422928 stepsize 0.0001
# [step 557] neg-log-likelihood -1121.965054 stepsize 0.0001
# [step 558] neg-log-likelihood -1116.248643 stepsize 0.0001
# [step 559] neg-log-likelihood -1114.407391 stepsize 0.0001
# [step 560] neg-log-likelihood -1111.885196 stepsize 0.0001
# [step 561] neg-log-likelihood -1108.571916 stepsize 0.0001
# [step 562] neg-log-likelihood -1103.665662 stepsize 0.0001
# [step 563] neg-log-likelihood -1108.819282 stepsize 0.0001
# [step 564] neg-log-likelihood -1097.553545 stepsize 0.0001
# [step 565] neg-log-likelihood -1097.688870 stepsize 0.0001
# [step 566] neg-log-likelihood -1093.786854 stepsize 0.0001
# [step 567] neg-log-likelihood -1090.978166 stepsize 0.0001
# [step 568] neg-log-likelihood -1086.902540 stepsize 0.0001
# [step 569] neg-log-likelihood -1083.401580 stepsize 0.0001
# [step 570] neg-log-likelihood -1082.227313 stepsize 0.0001
# [step 571] neg-log-likelihood -1078.810028 stepsize 0.0001
# [step 572] neg-log-likelihood -1078.857008 stepsize 0.0001
# [step 573] neg-log-likelihood -1074.757870 stepsize 0.0001
# [step 574] neg-log-likelihood -1074.137023 stepsize 0.0001
# [step 575] neg-log-likelihood -1067.513752 stepsize 0.0001
# [step 576] neg-log-likelihood -1067.295739 stepsize 0.0001
# [step 577] neg-log-likelihood -1062.417148 stepsize 0.0001
# [step 578] neg-log-likelihood -1055.730505 stepsize 0.0001
# [step 579] neg-log-likelihood -1048.798120 stepsize 0.0001
# [step 580] neg-log-likelihood -1038.799471 stepsize 0.0001
# [step 581] neg-log-likelihood -1033.368917 stepsize 0.0001
# [step 582] neg-log-likelihood -1024.991127 stepsize 0.0001
# [step 583] neg-log-likelihood -1017.950925 stepsize 0.0001
# [step 584] neg-log-likelihood -1008.935173 stepsize 0.0001
# [step 585] neg-log-likelihood -999.066091 stepsize 0.0001
# [step 586] neg-log-likelihood -989.795076 stepsize 0.0001
# [step 587] neg-log-likelihood -980.014054 stepsize 0.0001
# [step 588] neg-log-likelihood -969.779020 stepsize 0.0001
# [step 589] neg-log-likelihood -961.482190 stepsize 0.0001
# [step 590] neg-log-likelihood -939.610757 stepsize 0.0001
# [step 591] neg-log-likelihood -921.070267 stepsize 0.0001
# [step 592] neg-log-likelihood -911.800893 stepsize 0.0001
# [step 593] neg-log-likelihood -894.367842 stepsize 0.0001
# [step 594] neg-log-likelihood -885.146242 stepsize 0.0001
# [step 595] neg-log-likelihood -873.511716 stepsize 0.0001
# [step 596] neg-log-likelihood -844.946514 stepsize 0.0001
# [step 597] neg-log-likelihood -813.408583 stepsize 0.0001
# [step 598] neg-log-likelihood -771.196330 stepsize 0.0001
# [step 599] neg-log-likelihood -718.483059 stepsize 0.0001
# kernel initialization ...
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i     f              |g|
#     00s00  003   1.976396e+02   1.093064e+04
#     00s03  012   1.366904e+02   6.141449e+00
#     00s05  020   1.356241e+02   1.720387e-01
#     00s06  025   1.356189e+02   3.167811e-10
# Runtime:     00s06
# Optimization status: Converged
#
# negative log-likelihood compute
# [step   0] neg-log-likelihood -605.132060 stepsize 0.0001
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   1] neg-log-likelihood -632.415611 stepsize 0.0001
# [step   2] neg-log-likelihood -637.967336 stepsize 0.0001
# [step   3] neg-log-likelihood -631.341815 stepsize 0.0001
# [step   4] neg-log-likelihood -622.447454 stepsize 0.0001
# [step   5] neg-log-likelihood -622.040442 stepsize 0.0001
# [step   6] neg-log-likelihood -629.118462 stepsize 0.0001
# [step   7] neg-log-likelihood -640.489737 stepsize 0.0001
# [step   8] neg-log-likelihood -651.429221 stepsize 0.0001
# [step   9] neg-log-likelihood -664.417022 stepsize 0.0001
# [step  10] neg-log-likelihood -674.096822 stepsize 0.0001
# [step  11] neg-log-likelihood -687.027459 stepsize 0.0001
# [step  12] neg-log-likelihood -703.392483 stepsize 0.0001
# [step  13] neg-log-likelihood -719.407577 stepsize 0.0001
# [step  14] neg-log-likelihood -727.647970 stepsize 0.0001
# [step  15] neg-log-likelihood -737.720099 stepsize 0.0001
# [step  16] neg-log-likelihood -750.489013 stepsize 0.0001
# [step  17] neg-log-likelihood -763.038287 stepsize 0.0001
# [step  18] neg-log-likelihood -772.623413 stepsize 0.0001
# [step  19] neg-log-likelihood -784.282689 stepsize 0.0001
# [step  20] neg-log-likelihood -797.159055 stepsize 0.0001
# [step  21] neg-log-likelihood -802.864780 stepsize 0.0001
# [step  22] neg-log-likelihood -810.278649 stepsize 0.0001
# [step  23] neg-log-likelihood -817.989927 stepsize 0.0001
# [step  24] neg-log-likelihood -825.861226 stepsize 0.0001
# [step  25] neg-log-likelihood -834.069461 stepsize 0.0001
# [step  26] neg-log-likelihood -842.567271 stepsize 0.0001
# [step  27] neg-log-likelihood -851.102910 stepsize 0.0001
# [step  28] neg-log-likelihood -859.263466 stepsize 0.0001
# [step  29] neg-log-likelihood -867.318975 stepsize 0.0001
# [step  30] neg-log-likelihood -875.630720 stepsize 0.0001
# [step  31] neg-log-likelihood -884.272447 stepsize 0.0001
# [step  32] neg-log-likelihood -893.413848 stepsize 0.0001
# [step  33] neg-log-likelihood -903.150518 stepsize 0.0001
# [step  34] neg-log-likelihood -911.851435 stepsize 0.0001
# [step  35] neg-log-likelihood -920.197244 stepsize 0.0001
# [step  36] neg-log-likelihood -929.040014 stepsize 0.0001
# [step  37] neg-log-likelihood -939.212510 stepsize 0.0001
# [step  38] neg-log-likelihood -950.328403 stepsize 0.0001
# [step  39] neg-log-likelihood -954.959911 stepsize 0.0001
# [step  40] neg-log-likelihood -961.723180 stepsize 0.0001
# [step  41] neg-log-likelihood -968.948318 stepsize 0.0001
# [step  42] neg-log-likelihood -976.993287 stepsize 0.0001
# [step  43] neg-log-likelihood -985.732226 stepsize 0.0001
# [step  44] neg-log-likelihood -993.750106 stepsize 0.0001
# [step  45] neg-log-likelihood -1001.412061 stepsize 0.0001
# [step  46] neg-log-likelihood -1008.961559 stepsize 0.0001
# [step  47] neg-log-likelihood -1016.238457 stepsize 0.0001
# [step  48] neg-log-likelihood -1023.937236 stepsize 0.0001
# [step  49] neg-log-likelihood -1030.987938 stepsize 0.0001
# [step  50] neg-log-likelihood -1037.899836 stepsize 0.0001
# [step  51] neg-log-likelihood -1046.488212 stepsize 0.0001
# [step  52] neg-log-likelihood -1056.751007 stepsize 0.0001
# [step  53] neg-log-likelihood -1065.864773 stepsize 0.0001
# [step  54] neg-log-likelihood -1072.114988 stepsize 0.0001
# [step  55] neg-log-likelihood -1078.337400 stepsize 0.0001
# [step  56] neg-log-likelihood -1085.393213 stepsize 0.0001
# [step  57] neg-log-likelihood -1090.689267 stepsize 0.0001
# [step  58] neg-log-likelihood -1097.815979 stepsize 0.0001
# [step  59] neg-log-likelihood -1105.436177 stepsize 0.0001
# [step  60] neg-log-likelihood -1110.786285 stepsize 0.0001
# [step  61] neg-log-likelihood -1123.272110 stepsize 0.0001
# [step  62] neg-log-likelihood -1128.198629 stepsize 0.0001
# [step  63] neg-log-likelihood -1130.972299 stepsize 0.0001
# [step  64] neg-log-likelihood -1139.698708 stepsize 0.0001
# [step  65] neg-log-likelihood -1143.623775 stepsize 0.0001
# [step  66] neg-log-likelihood -1147.901367 stepsize 0.0001
# [step  67] neg-log-likelihood -1155.978171 stepsize 0.0001
# [step  68] neg-log-likelihood -1160.134833 stepsize 0.0001
# [step  69] neg-log-likelihood -1162.660013 stepsize 0.0001
# [step  70] neg-log-likelihood -1172.098079 stepsize 0.0001
# [step  71] neg-log-likelihood -1175.151268 stepsize 0.0001
# [step  72] neg-log-likelihood -1177.239649 stepsize 0.0001
# [step  73] neg-log-likelihood -1184.855162 stepsize 0.0001
# [step  74] neg-log-likelihood -1183.754351 stepsize 0.0001
# [step  75] neg-log-likelihood -1194.570615 stepsize 0.0001
# [step  76] neg-log-likelihood -1192.540495 stepsize 0.0001
# [step  77] neg-log-likelihood -1191.013494 stepsize 0.0001
# [step  78] neg-log-likelihood -1197.151656 stepsize 0.0001
# [step  79] neg-log-likelihood -1200.030708 stepsize 0.0001
# [step  80] neg-log-likelihood -1201.832663 stepsize 0.0001
# [step  81] neg-log-likelihood -1203.589093 stepsize 0.0001
# [step  82] neg-log-likelihood -1207.037820 stepsize 0.0001
# [step  83] neg-log-likelihood -1208.432326 stepsize 0.0001
# [step  84] neg-log-likelihood -1212.094547 stepsize 0.0001
# [step  85] neg-log-likelihood -1215.450985 stepsize 0.0001
# [step  86] neg-log-likelihood -1218.019738 stepsize 0.0001
# [step  87] neg-log-likelihood -1220.854394 stepsize 0.0001
# [step  88] neg-log-likelihood -1220.846485 stepsize 0.0001
# [step  89] neg-log-likelihood -1225.889002 stepsize 0.0001
# [step  90] neg-log-likelihood -1228.105981 stepsize 0.0001
# [step  91] neg-log-likelihood -1232.312923 stepsize 0.0001
# [step  92] neg-log-likelihood -1234.392290 stepsize 0.0001
# [step  93] neg-log-likelihood -1237.443279 stepsize 0.0001
# [step  94] neg-log-likelihood -1238.651447 stepsize 0.0001
# [step  95] neg-log-likelihood -1242.136257 stepsize 0.0001
# [step  96] neg-log-likelihood -1245.636409 stepsize 0.0001
# [step  97] neg-log-likelihood -1247.562940 stepsize 0.0001
# [step  98] neg-log-likelihood -1253.058202 stepsize 0.0001
# [step  99] neg-log-likelihood -1253.698382 stepsize 0.0001
# [step 100] neg-log-likelihood -1260.188955 stepsize 0.0001
# [step 101] neg-log-likelihood -1258.787352 stepsize 0.0001
# [step 102] neg-log-likelihood -1259.916004 stepsize 0.0001
# [step 103] neg-log-likelihood -1263.272303 stepsize 0.0001
# [step 104] neg-log-likelihood -1264.604054 stepsize 0.0001
# [step 105] neg-log-likelihood -1270.441247 stepsize 0.0001
# [step 106] neg-log-likelihood -1272.450310 stepsize 0.0001
# [step 107] neg-log-likelihood -1275.885611 stepsize 0.0001
# [step 108] neg-log-likelihood -1282.732362 stepsize 0.0001
# [step 109] neg-log-likelihood -1280.572951 stepsize 0.0001
# [step 110] neg-log-likelihood -1281.363952 stepsize 0.0001
# [step 111] neg-log-likelihood -1285.085097 stepsize 0.0001
# [step 112] neg-log-likelihood -1291.286440 stepsize 0.0001
# [step 113] neg-log-likelihood -1292.341853 stepsize 0.0001
# [step 114] neg-log-likelihood -1295.773977 stepsize 0.0001
# [step 115] neg-log-likelihood -1298.757757 stepsize 0.0001
# [step 116] neg-log-likelihood -1302.667706 stepsize 0.0001
# [step 117] neg-log-likelihood -1306.664668 stepsize 0.0001
# [step 118] neg-log-likelihood -1304.772854 stepsize 0.0001
# [step 119] neg-log-likelihood -1308.848763 stepsize 0.0001
# [step 120] neg-log-likelihood -1314.090303 stepsize 0.0001
# [step 121] neg-log-likelihood -1312.546635 stepsize 0.0001
# [step 122] neg-log-likelihood -1319.789004 stepsize 0.0001
# [step 123] neg-log-likelihood -1321.810440 stepsize 0.0001
# [step 124] neg-log-likelihood -1324.836109 stepsize 0.0001
# [step 125] neg-log-likelihood -1328.452302 stepsize 0.0001
# [step 126] neg-log-likelihood -1327.449252 stepsize 0.0001
# [step 127] neg-log-likelihood -1330.893995 stepsize 0.0001
# [step 128] neg-log-likelihood -1338.123089 stepsize 0.0001
# [step 129] neg-log-likelihood -1340.892747 stepsize 0.0001
# [step 130] neg-log-likelihood -1341.437760 stepsize 0.0001
# [step 131] neg-log-likelihood -1344.954935 stepsize 0.0001
# [step 132] neg-log-likelihood -1348.816821 stepsize 0.0001
# [step 133] neg-log-likelihood -1349.974332 stepsize 0.0001
# [step 134] neg-log-likelihood -1352.787594 stepsize 0.0001
# [step 135] neg-log-likelihood -1356.275256 stepsize 0.0001
# [step 136] neg-log-likelihood -1357.963023 stepsize 0.0001
# [step 137] neg-log-likelihood -1361.753250 stepsize 0.0001
# [step 138] neg-log-likelihood -1360.434837 stepsize 0.0001
# [step 139] neg-log-likelihood -1364.466041 stepsize 0.0001
# [step 140] neg-log-likelihood -1370.071362 stepsize 0.0001
# [step 141] neg-log-likelihood -1371.683186 stepsize 0.0001
# [step 142] neg-log-likelihood -1373.982427 stepsize 0.0001
# [step 143] neg-log-likelihood -1374.885346 stepsize 0.0001
# [step 144] neg-log-likelihood -1377.556132 stepsize 0.0001
# [step 145] neg-log-likelihood -1381.387022 stepsize 0.0001
# [step 146] neg-log-likelihood -1379.591709 stepsize 0.0001
# [step 147] neg-log-likelihood -1385.328791 stepsize 0.0001
# [step 148] neg-log-likelihood -1385.197087 stepsize 0.0001
# [step 149] neg-log-likelihood -1386.487435 stepsize 0.0001
# [step 150] neg-log-likelihood -1391.101769 stepsize 0.0001
# [step 151] neg-log-likelihood -1392.265498 stepsize 0.0001
# [step 152] neg-log-likelihood -1390.893455 stepsize 0.0001
# [step 153] neg-log-likelihood -1396.036527 stepsize 0.0001
# [step 154] neg-log-likelihood -1400.190205 stepsize 0.0001
# [step 155] neg-log-likelihood -1398.019591 stepsize 0.0001
# [step 156] neg-log-likelihood -1398.106889 stepsize 0.0001
# [step 157] neg-log-likelihood -1402.280801 stepsize 0.0001
# [step 158] neg-log-likelihood -1406.150541 stepsize 0.0001
# [step 159] neg-log-likelihood -1404.876509 stepsize 0.0001
# [step 160] neg-log-likelihood -1411.466093 stepsize 0.0001
# [step 161] neg-log-likelihood -1409.719410 stepsize 0.0001
# [step 162] neg-log-likelihood -1411.027691 stepsize 0.0001
# [step 163] neg-log-likelihood -1415.773679 stepsize 0.0001
# [step 164] neg-log-likelihood -1418.174009 stepsize 0.0001
# [step 165] neg-log-likelihood -1418.705505 stepsize 0.0001
# [step 166] neg-log-likelihood -1422.367258 stepsize 0.0001
# [step 167] neg-log-likelihood -1425.967329 stepsize 0.0001
# [step 168] neg-log-likelihood -1423.566974 stepsize 0.0001
# [step 169] neg-log-likelihood -1424.786990 stepsize 0.0001
# [step 170] neg-log-likelihood -1428.449924 stepsize 0.0001
# [step 171] neg-log-likelihood -1427.471390 stepsize 0.0001
# [step 172] neg-log-likelihood -1430.989711 stepsize 0.0001
# [step 173] neg-log-likelihood -1430.869399 stepsize 0.0001
# [step 174] neg-log-likelihood -1432.328038 stepsize 0.0001
# [step 175] neg-log-likelihood -1433.280719 stepsize 0.0001
# [step 176] neg-log-likelihood -1434.583708 stepsize 0.0001
# [step 177] neg-log-likelihood -1438.151198 stepsize 0.0001
# [step 178] neg-log-likelihood -1436.052079 stepsize 0.0001
# [step 179] neg-log-likelihood -1438.449170 stepsize 0.0001
# [step 180] neg-log-likelihood -1442.773087 stepsize 0.0001
# [step 181] neg-log-likelihood -1442.685159 stepsize 0.0001
# [step 182] neg-log-likelihood -1445.288952 stepsize 0.0001
# [step 183] neg-log-likelihood -1441.911442 stepsize 0.0001
# [step 184] neg-log-likelihood -1447.850647 stepsize 0.0001
# [step 185] neg-log-likelihood -1448.857270 stepsize 0.0001
# [step 186] neg-log-likelihood -1448.927479 stepsize 0.0001
# [step 187] neg-log-likelihood -1451.481293 stepsize 0.0001
# [step 188] neg-log-likelihood -1452.399479 stepsize 0.0001
# [step 189] neg-log-likelihood -1451.460675 stepsize 0.0001
# [step 190] neg-log-likelihood -1451.428400 stepsize 0.0001
# [step 191] neg-log-likelihood -1451.372685 stepsize 0.0001
# [step 192] neg-log-likelihood -1453.074309 stepsize 0.0001
# [step 193] neg-log-likelihood -1453.253233 stepsize 0.0001
# [step 194] neg-log-likelihood -1453.141858 stepsize 0.0001
# ...
# [step 329] neg-log-likelihood -1493.401636 stepsize 0.0001
# [step 330] neg-log-likelihood -1496.530221 stepsize 0.0001
# [step 331] neg-log-likelihood -1496.064376 stepsize 0.0001
# [step 332] neg-log-likelihood -1497.354976 stepsize 0.0001
# [step 333] neg-log-likelihood -1496.077372 stepsize 0.0001
# [step 334] neg-log-likelihood -1496.305967 stepsize 0.0001
# [step 335] neg-log-likelihood -1497.656020 stepsize 0.0001
# [step 336] neg-log-likelihood -1496.520338 stepsize 0.0001
# [step 337] neg-log-likelihood -1494.128231 stepsize 0.0001
# [step 338] neg-log-likelihood -1496.833814 stepsize 0.0001
# [step 339] neg-log-likelihood -1501.233372 stepsize 0.0001
# [step 340] neg-log-likelihood -1496.964816 stepsize 0.0001
# [step 341] neg-log-likelihood -1500.419935 stepsize 0.0001
# [step 342] neg-log-likelihood -1498.141737 stepsize 0.0001
# [step 343] neg-log-likelihood -1498.232303 stepsize 0.0001
# [step 344] neg-log-likelihood -1500.743353 stepsize 0.0001
# [step 345] neg-log-likelihood -1501.177637 stepsize 0.0001
# [step 346] neg-log-likelihood -1499.371159 stepsize 0.0001
# [step 347] neg-log-likelihood -1498.982121 stepsize 0.0001
# [step 348] neg-log-likelihood -1501.143810 stepsize 0.0001
# [step 349] neg-log-likelihood -1499.872154 stepsize 0.0001
# [step 350] neg-log-likelihood -1501.490620 stepsize 0.0001
# [step 351] neg-log-likelihood -1502.292609 stepsize 0.0001
# [step 352] neg-log-likelihood -1503.990033 stepsize 0.0001
# [step 353] neg-log-likelihood -1501.977590 stepsize 0.0001
# [step 354] neg-log-likelihood -1502.854812 stepsize 0.0001
# [step 355] neg-log-likelihood -1504.562193 stepsize 0.0001
# [step 356] neg-log-likelihood -1506.744517 stepsize 0.0001
# [step 357] neg-log-likelihood -1505.257664 stepsize 0.0001
# [step 358] neg-log-likelihood -1505.919465 stepsize 0.0001
# [step 359] neg-log-likelihood -1507.081054 stepsize 0.0001
# [step 360] neg-log-likelihood -1505.280457 stepsize 0.0001
# [step 361] neg-log-likelihood -1504.878845 stepsize 0.0001
# [step 362] neg-log-likelihood -1509.205410 stepsize 0.0001
# [step 363] neg-log-likelihood -1507.470566 stepsize 0.0001
# [step 364] neg-log-likelihood -1505.641791 stepsize 0.0001
# [step 365] neg-log-likelihood -1506.801544 stepsize 0.0001
# [step 366] neg-log-likelihood -1507.372458 stepsize 0.0001
# [step 367] neg-log-likelihood -1506.323443 stepsize 0.0001
# [step 368] neg-log-likelihood -1508.118218 stepsize 0.0001
# [step 369] neg-log-likelihood -1508.313823 stepsize 0.0001
# [step 370] neg-log-likelihood -1512.825631 stepsize 0.0001
# [step 371] neg-log-likelihood -1511.105789 stepsize 0.0001
# [step 372] neg-log-likelihood -1510.108353 stepsize 0.0001
# [step 373] neg-log-likelihood -1510.893295 stepsize 0.0001
# [step 374] neg-log-likelihood -1509.372103 stepsize 0.0001
# [step 375] neg-log-likelihood -1511.870818 stepsize 0.0001
# [step 376] neg-log-likelihood -1510.382324 stepsize 0.0001
# [step 377] neg-log-likelihood -1514.597341 stepsize 0.0001
# [step 378] neg-log-likelihood -1515.455726 stepsize 0.0001
# [step 379] neg-log-likelihood -1513.001770 stepsize 0.0001
# [step 380] neg-log-likelihood -1515.248614 stepsize 0.0001
# [step 381] neg-log-likelihood -1515.153018 stepsize 0.0001
# [step 382] neg-log-likelihood -1511.318524 stepsize 0.0001
# [step 383] neg-log-likelihood -1515.481829 stepsize 0.0001
# [step 384] neg-log-likelihood -1518.439953 stepsize 0.0001
# [step 385] neg-log-likelihood -1518.234909 stepsize 0.0001
# [step 386] neg-log-likelihood -1515.290323 stepsize 0.0001
# [step 387] neg-log-likelihood -1513.956853 stepsize 0.0001
# [step 388] neg-log-likelihood -1515.653890 stepsize 0.0001
# [step 389] neg-log-likelihood -1514.789499 stepsize 0.0001
# [step 390] neg-log-likelihood -1514.282065 stepsize 0.0001
# [step 391] neg-log-likelihood -1516.423518 stepsize 0.0001
# [step 392] neg-log-likelihood -1516.986703 stepsize 0.0001
# [step 393] neg-log-likelihood -1515.721707 stepsize 0.0001
# [step 394] neg-log-likelihood -1519.742374 stepsize 0.0001
# [step 395] neg-log-likelihood -1518.181695 stepsize 0.0001
# [step 396] neg-log-likelihood -1519.148239 stepsize 0.0001
# [step 397] neg-log-likelihood -1521.866139 stepsize 0.0001
# [step 398] neg-log-likelihood -1518.175067 stepsize 0.0001
# [step 399] neg-log-likelihood -1522.486985 stepsize 0.0001
# [step 400] neg-log-likelihood -1523.614093 stepsize 0.0001
# [step 401] neg-log-likelihood -1519.433185 stepsize 0.0001
# [step 402] neg-log-likelihood -1522.391391 stepsize 0.0001
# [step 403] neg-log-likelihood -1521.744310 stepsize 0.0001
# [step 404] neg-log-likelihood -1521.265769 stepsize 0.0001
# [step 405] neg-log-likelihood -1520.821139 stepsize 0.0001
# [step 406] neg-log-likelihood -1521.401290 stepsize 0.0001
# [step 407] neg-log-likelihood -1517.986134 stepsize 0.0001
# [step 408] neg-log-likelihood -1522.319007 stepsize 0.0001
# [step 409] neg-log-likelihood -1521.467583 stepsize 0.0001
# [step 410] neg-log-likelihood -1524.021698 stepsize 0.0001
# [step 411] neg-log-likelihood -1523.759845 stepsize 0.0001
# [step 412] neg-log-likelihood -1525.019970 stepsize 0.0001
# [step 413] neg-log-likelihood -1525.167133 stepsize 0.0001
# [step 414] neg-log-likelihood -1524.908408 stepsize 0.0001
# [step 415] neg-log-likelihood -1522.973642 stepsize 0.0001
# [step 416] neg-log-likelihood -1526.862144 stepsize 0.0001
# [step 417] neg-log-likelihood -1525.853032 stepsize 0.0001
# [step 418] neg-log-likelihood -1525.583591 stepsize 0.0001
# [step 419] neg-log-likelihood -1523.946650 stepsize 0.0001
# [step 420] neg-log-likelihood -1526.689044 stepsize 0.0001
# [step 421] neg-log-likelihood -1525.086171 stepsize 0.0001
# [step 422] neg-log-likelihood -1525.769507 stepsize 0.0001
# [step 423] neg-log-likelihood -1528.895969 stepsize 0.0001
# [step 424] neg-log-likelihood -1527.450399 stepsize 0.0001
# [step 425] neg-log-likelihood -1526.500756 stepsize 0.0001
# [step 426] neg-log-likelihood -1529.517995 stepsize 0.0001
# [step 427] neg-log-likelihood -1530.303092 stepsize 0.0001
# [step 428] neg-log-likelihood -1530.923577 stepsize 0.0001
# [step 429] neg-log-likelihood -1528.569256 stepsize 0.0001
# [step 430] neg-log-likelihood -1527.710221 stepsize 0.0001
# [step 431] neg-log-likelihood -1527.629378 stepsize 0.0001
# [step 432] neg-log-likelihood -1529.396831 stepsize 0.0001
# [step 433] neg-log-likelihood -1531.680985 stepsize 0.0001
# [step 434] neg-log-likelihood -1531.977128 stepsize 0.0001
# [step 435] neg-log-likelihood -1530.890470 stepsize 0.0001
# [step 436] neg-log-likelihood -1536.500217 stepsize 0.0001
# [step 437] neg-log-likelihood -1532.155449 stepsize 0.0001
# [step 438] neg-log-likelihood -1530.406295 stepsize 0.0001
# [step 439] neg-log-likelihood -1535.878729 stepsize 0.0001
# [step 440] neg-log-likelihood -1532.358795 stepsize 0.0001
# [step 441] neg-log-likelihood -1533.579218 stepsize 0.0001
# [step 442] neg-log-likelihood -1535.723878 stepsize 0.0001
# [step 443] neg-log-likelihood -1534.949029 stepsize 0.0001
# [step 444] neg-log-likelihood -1533.805179 stepsize 0.0001
# [step 445] neg-log-likelihood -1535.644645 stepsize 0.0001
# [step 446] neg-log-likelihood -1532.889308 stepsize 0.0001
# [step 447] neg-log-likelihood -1533.836452 stepsize 0.0001
# [step 448] neg-log-likelihood -1533.221467 stepsize 0.0001
# [step 449] neg-log-likelihood -1533.516007 stepsize 0.0001
# [step 450] neg-log-likelihood -1533.975750 stepsize 0.0001
# [step 451] neg-log-likelihood -1537.380723 stepsize 0.0001
# [step 452] neg-log-likelihood -1536.123040 stepsize 0.0001
# [step 453] neg-log-likelihood -1536.194180 stepsize 0.0001
# [step 454] neg-log-likelihood -1535.769740 stepsize 0.0001
# [step 455] neg-log-likelihood -1537.511460 stepsize 0.0001
# [step 456] neg-log-likelihood -1536.369813 stepsize 0.0001
# [step 457] neg-log-likelihood -1537.636635 stepsize 0.0001
# [step 458] neg-log-likelihood -1535.895698 stepsize 0.0001
# [step 459] neg-log-likelihood -1539.454903 stepsize 0.0001
# [step 460] neg-log-likelihood -1540.157734 stepsize 0.0001
# [step 461] neg-log-likelihood -1537.738413 stepsize 0.0001
# [step 462] neg-log-likelihood -1537.170500 stepsize 0.0001
# [step 463] neg-log-likelihood -1539.726530 stepsize 0.0001
# [step 464] neg-log-likelihood -1541.836801 stepsize 0.0001
# [step 465] neg-log-likelihood -1539.570306 stepsize 0.0001
# [step 466] neg-log-likelihood -1541.568363 stepsize 0.0001
# [step 467] neg-log-likelihood -1541.304369 stepsize 0.0001
# [step 468] neg-log-likelihood -1543.556178 stepsize 0.0001
# [step 469] neg-log-likelihood -1543.703471 stepsize 0.0001
# [step 470] neg-log-likelihood -1542.610309 stepsize 0.0001
# [step 471] neg-log-likelihood -1540.024724 stepsize 0.0001
# [step 472] neg-log-likelihood -1545.730503 stepsize 0.0001
# [step 473] neg-log-likelihood -1545.933012 stepsize 0.0001
# [step 474] neg-log-likelihood -1543.659528 stepsize 0.0001
# [step 475] neg-log-likelihood -1543.791474 stepsize 0.0001
# [step 476] neg-log-likelihood -1546.327786 stepsize 0.0001
# [step 477] neg-log-likelihood -1546.329558 stepsize 0.0001
# [step 478] neg-log-likelihood -1543.220882 stepsize 0.0001
# [step 479] neg-log-likelihood -1544.455978 stepsize 0.0001
# [step 480] neg-log-likelihood -1546.793568 stepsize 0.0001
# [step 481] neg-log-likelihood -1547.113333 stepsize 0.0001
# [step 482] neg-log-likelihood -1548.806036 stepsize 0.0001
# [step 483] neg-log-likelihood -1544.752205 stepsize 0.0001
# [step 484] neg-log-likelihood -1548.738967 stepsize 0.0001
# [step 485] neg-log-likelihood -1545.452178 stepsize 0.0001
# [step 486] neg-log-likelihood -1547.508237 stepsize 0.0001
# [step 487] neg-log-likelihood -1548.268100 stepsize 0.0001
# [step 488] neg-log-likelihood -1549.844887 stepsize 0.0001
# [step 489] neg-log-likelihood -1547.331070 stepsize 0.0001
# [step 490] neg-log-likelihood -1548.387096 stepsize 0.0001
# [step 491] neg-log-likelihood -1550.233535 stepsize 0.0001
# [step 492] neg-log-likelihood -1549.248570 stepsize 0.0001
# [step 493] neg-log-likelihood -1548.032990 stepsize 0.0001
# [step 494] neg-log-likelihood -1550.822956 stepsize 0.0001
# [step 495] neg-log-likelihood -1550.612950 stepsize 0.0001
# [step 496] neg-log-likelihood -1551.355706 stepsize 0.0001
# [step 497] neg-log-likelihood -1555.968346 stepsize 0.0001
# [step 498] neg-log-likelihood -1551.005830 stepsize 0.0001
# [step 499] neg-log-likelihood -1556.663574 stepsize 0.0001
# [step 500] neg-log-likelihood -1554.600989 stepsize 0.0001
# [step 501] neg-log-likelihood -1552.457215 stepsize 0.0001
# [step 502] neg-log-likelihood -1556.074742 stepsize 0.0001
# [step 503] neg-log-likelihood -1553.005396 stepsize 0.0001
# [step 504] neg-log-likelihood -1555.678505 stepsize 0.0001
# [step 505] neg-log-likelihood -1550.753904 stepsize 0.0001
# [step 506] neg-log-likelihood -1553.663473 stepsize 0.0001
# [step 507] neg-log-likelihood -1552.871506 stepsize 0.0001
# [step 508] neg-log-likelihood -1549.367952 stepsize 0.0001
# [step 509] neg-log-likelihood -1551.738546 stepsize 0.0001
# [step 510] neg-log-likelihood -1553.485411 stepsize 0.0001
# [step 511] neg-log-likelihood -1552.038383 stepsize 0.0001
# [step 512] neg-log-likelihood -1556.933603 stepsize 0.0001
# [step 513] neg-log-likelihood -1556.182076 stepsize 0.0001
# [step 514] neg-log-likelihood -1552.359789 stepsize 0.0001
# [step 515] neg-log-likelihood -1553.230228 stepsize 0.0001
# [step 516] neg-log-likelihood -1556.707996 stepsize 0.0001
# [step 517] neg-log-likelihood -1556.949618 stepsize 0.0001
# [step 518] neg-log-likelihood -1552.135308 stepsize 0.0001
# [step 519] neg-log-likelihood -1552.042481 stepsize 0.0001
# [step 520] neg-log-likelihood -1556.415587 stepsize 0.0001
# [step 521] neg-log-likelihood -1554.883410 stepsize 0.0001
# [step 522] neg-log-likelihood -1553.229900 stepsize 0.0001
# [step 523] neg-log-likelihood -1555.277166 stepsize 0.0001
# [step 524] neg-log-likelihood -1558.872217 stepsize 0.0001
# [step 525] neg-log-likelihood -1555.071823 stepsize 0.0001
# [step 526] neg-log-likelihood -1552.042331 stepsize 0.0001
# [step 527] neg-log-likelihood -1553.907606 stepsize 0.0001
# [step 528] neg-log-likelihood -1552.852736 stepsize 0.0001
# [step 529] neg-log-likelihood -1553.935295 stepsize 0.0001
# [step 530] neg-log-likelihood -1552.856459 stepsize 0.0001
# [step 531] neg-log-likelihood -1552.377253 stepsize 0.0001
# [step 532] neg-log-likelihood -1556.469994 stepsize 0.0001
# [step 533] neg-log-likelihood -1556.134163 stepsize 0.0001
# [step 534] neg-log-likelihood -1556.945073 stepsize 0.0001
# [step 535] neg-log-likelihood -1558.125972 stepsize 0.0001
# [step 536] neg-log-likelihood -1554.519132 stepsize 0.0001
# [step 537] neg-log-likelihood -1555.980816 stepsize 0.0001
# [step 538] neg-log-likelihood -1554.892293 stepsize 0.0001
# [step 539] neg-log-likelihood -1555.572410 stepsize 0.0001
# [step 540] neg-log-likelihood -1555.891892 stepsize 0.0001
# [step 541] neg-log-likelihood -1556.851572 stepsize 0.0001
# [step 542] neg-log-likelihood -1556.434480 stepsize 0.0001
# [step 543] neg-log-likelihood -1557.691765 stepsize 0.0001
# [step 544] neg-log-likelihood -1558.700069 stepsize 0.0001
# [step 545] neg-log-likelihood -1557.683539 stepsize 0.0001
# [step 546] neg-log-likelihood -1556.869810 stepsize 0.0001
# [step 547] neg-log-likelihood -1561.913746 stepsize 0.0001
# [step 548] neg-log-likelihood -1557.944111 stepsize 0.0001
# [step 549] neg-log-likelihood -1558.856033 stepsize 0.0001
# [step 550] neg-log-likelihood -1557.749652 stepsize 0.0001
# [step 551] neg-log-likelihood -1556.441392 stepsize 0.0001
# [step 552] neg-log-likelihood -1556.688007 stepsize 0.0001
# [step 553] neg-log-likelihood -1558.723418 stepsize 0.0001
# [step 554] neg-log-likelihood -1555.113736 stepsize 0.0001
# [step 555] neg-log-likelihood -1558.670899 stepsize 0.0001
# [step 556] neg-log-likelihood -1557.953721 stepsize 0.0001
# [step 557] neg-log-likelihood -1560.365623 stepsize 0.0001
# [step 558] neg-log-likelihood -1557.918281 stepsize 0.0001
# [step 559] neg-log-likelihood -1558.365204 stepsize 0.0001
# [step 560] neg-log-likelihood -1560.791626 stepsize 0.0001
# [step 561] neg-log-likelihood -1559.697768 stepsize 0.0001
# [step 562] neg-log-likelihood -1561.176841 stepsize 0.0001
# [step 563] neg-log-likelihood -1560.421728 stepsize 0.0001
# [step 564] neg-log-likelihood -1556.272553 stepsize 0.0001
# [step 565] neg-log-likelihood -1557.322543 stepsize 0.0001
# [step 566] neg-log-likelihood -1562.090862 stepsize 0.0001
# [step 567] neg-log-likelihood -1557.394767 stepsize 0.0001
# [step 568] neg-log-likelihood -1559.838073 stepsize 0.0001
# [step 569] neg-log-likelihood -1560.177991 stepsize 0.0001
# [step 570] neg-log-likelihood -1560.763681 stepsize 0.0001
# [step 571] neg-log-likelihood -1559.325122 stepsize 0.0001
# [step 572] neg-log-likelihood -1556.544157 stepsize 0.0001
# [step 573] neg-log-likelihood -1557.381407 stepsize 0.0001
# [step 574] neg-log-likelihood -1558.012356 stepsize 0.0001
# [step 575] neg-log-likelihood -1560.309320 stepsize 0.0001
# [step 576] neg-log-likelihood -1559.975686 stepsize 0.0001
# [step 577] neg-log-likelihood -1559.552945 stepsize 0.0001
# [step 578] neg-log-likelihood -1556.177715 stepsize 0.0001
# [step 579] neg-log-likelihood -1560.338194 stepsize 0.0001
# [step 580] neg-log-likelihood -1561.308352 stepsize 0.0001
# [step 581] neg-log-likelihood -1561.005237 stepsize 0.0001
# [step 582] neg-log-likelihood -1557.189735 stepsize 0.0001
# [step 583] neg-log-likelihood -1561.730618 stepsize 0.0001
# [step 584] neg-log-likelihood -1557.860325 stepsize 0.0001
# [step 585] neg-log-likelihood -1556.914571 stepsize 0.0001
# [step 586] neg-log-likelihood -1555.571260 stepsize 0.0001
# [step 587] neg-log-likelihood -1556.612020 stepsize 0.0001
# [step 588] neg-log-likelihood -1555.482607 stepsize 0.0001
# [step 589] neg-log-likelihood -1559.080609 stepsize 0.0001
# [step 590] neg-log-likelihood -1555.931739 stepsize 0.0001
# [step 591] neg-log-likelihood -1556.576502 stepsize 0.0001
# [step 592] neg-log-likelihood -1556.420158 stepsize 0.0001
# [step 593] neg-log-likelihood -1556.685788 stepsize 0.0001
# [step 594] neg-log-likelihood -1554.178870 stepsize 0.0001
# [step 595] neg-log-likelihood -1558.597422 stepsize 0.0001
# [step 596] neg-log-likelihood -1554.120374 stepsize 0.0001
# [step 597] neg-log-likelihood -1557.604672 stepsize 0.0001
# [step 598] neg-log-likelihood -1556.034710 stepsize 0.0001
# [step 599] neg-log-likelihood -1554.234859 stepsize 0.0001

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 6.0*len(lambda_array))
plt.style.use('seaborn-white')

for i in np.arange(len(lambda_array)):
    ax = plt.subplot(len(lambda_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_nll_eu_array[i], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_nll_grass_array[i], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i]), \
                             r"Grassmann ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
                             fontsize = 15, loc='upper center', frameon=True)
    else:    
        ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f})".format(eta), r"Grassmann ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper center', frameon=True)
    plt.grid(1)
    plt.ylabel('negative log-likelihood', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_01_16_" + str(trail) + "_"
    file_tail = "_nll_iters_Grass_Eu.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %% [markdown]
# These plots show the comparison of learning trajectories for different regularization paramters $\lambda$. We see that the larger $\lambda$, the smoother the curve is. However, it introduces more biases.
# <img src="../figures/03_31_16_nll_iters_Grass_Eu_1_nearReg.png">

# %%
fig= plt.figure(2)
fig.set_size_inches(12.0, 6.0*len(lambda_array))
plt.style.use('seaborn-white')

for i in np.arange(len(lambda_array)):
    ax = plt.subplot(len(lambda_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_Hsig_array[i][:,0], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_Hsig_array[i][:,1], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"1st singular value ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i]), \
                             r"2nd singular value ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
                             fontsize = 15, loc='upper right', frameon=True)
    else:    
        ax.legend([h1, h2], [r"1st singular value ($\eta$ = {0:5.4f})".format(eta), r"2nd singular value ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper right', frameon=True)
    plt.grid(1)
    plt.ylabel('singular value', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_01_16_" + str(trail) + "_"
    file_tail = "_sig_iters_Grass_Eu.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
Ifsavefig = True
